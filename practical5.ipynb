# %%
def chatbot():
  print("Welcome to chatbot support")
  print("plz type 'bye'to exit.\n")
  while True:
      user=input("You:").lower()
      if user=="bye":
          print("Chatbot:Thank you have a nice day!!!")
      elif "hello" in user or "hi" in user:
          print("Chatbot:Welcome to chatbot support ,how can i help you?")
      elif "price" in user or "cost" in user:
          print("Chatbot:Our products start from Rs.899")
      elif "order" in user:
          print("Chatbot: you can place order on website")
      elif "refund" in user:
          print("Chatbot:refund is process within 7 days")
      elif "contact" in user:
          print("ChatBot:you can contact us on abc11@gmail.com")
      else:
          print("Chatbot:Sorry,I didn't understand,can you rephrase?") 
chatbot()
# Out:
# Welcome to chatbot support
# plz type 'bye'to exit.
# You: hi
# Chatbot:Welcome to chatbot support ,how can i help you?
# You: where place order
# Chatbot: you can place order on website
# You: from which price the products start
# Chatbot:Welcome to chatbot support ,how can i help you?
# You: price the products start
# Chatbot:Our products start from Rs.899
# You: refund policy
# Chatbot:refund is process within 7 days
# You: how to contact
# ChatBot:you can contact us on abc11@gmail.com
# You: discount available
# Chatbot:Sorry,I didn't understand,can you rephrase?
# You: bye
# Chatbot:Thank you have a nice day!!!
